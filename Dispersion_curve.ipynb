# %% [markdown]
# # Firstly, you need to install Lambwave library which I have mentioned below. this is build by https://github.com/franciscorotea. you can check his profile. He has some amazing content to share 👌

# %% [markdown]
# ## For more visit: https://github.com/franciscorotea/Lamb-Wave-Dispersion

# %%
pip install git+https://github.com/franciscorotea/Lamb-Wave-Dispersion
# Out:
# ...
#   Cloning https://github.com/franciscorotea/Lamb-Wave-Dispersion to c:\users\setuthacker\appdata\local\temp\pip-req-build-2qwooqhk
#   Resolved https://github.com/franciscorotea/Lamb-Wave-Dispersion to commit 59d7e64533158c384c1f21b754671582098505ca
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/franciscorotea/Lamb-Wave-Dispersion 'C:\Users\setuthacker\AppData\Local\Temp\pip-req-build-2qwooqhk'

# %%
import numpy as np
import matplotlib.pyplot as plt
from lambwaves import Lamb

"""
In order to set up the Lamb class, you will need the following 
parameters:
    
    thickness : Thickness of the plate, in mm.
    nmodes_sym : Number of symmetric modes to calculate.
    nmodes_antisym : Number of antisymmetric modes to calculate.
    fd_max : Maximum value of frequency × thickness to calculate, 
             in kHz × mm.
    vp_max : Maximum value of phase velocity to calculate, in m/s.
    c_L : Longitudinal wave velocity of the material, in m/s.
    c_S: Shear wave velocity of the material, in m/s. 
    
The following parameters are optional:
        
    c_R : Rayleigh wave velocity of the material, in m/s. 
    fd_points : Number of frequency × thickness points.
    vp_step : Increment between phase velocity intervals.
    material : Name of the material being analyzed.
    
"""
   
# You can obtain the values of c_L and c_S and an approximate value for
# c_R (if v > 0.3) from the material's mechanical properties by using 
# the following equations:

E = 200.9e9         # E = Young's modulus, in Pa.
p = 5300            # p = Density (rho), in kg/m3.
v = 0.2            # v = Poisson's ratio (nu).

c_L = np.sqrt(E*(1-v) / (p*(1+v)*(1-2*v)))
c_S = np.sqrt(E / (2*p*(1+v)))
c_R = c_S * ((0.862+1.14*v) / (1+v))

# Example: A 10 mm aluminum plate.

alum = Lamb(thickness=10, 
            nmodes_sym=5, 
            nmodes_antisym=5, 
            fd_max=10000, 
            vp_max=15000, 
            c_L=c_L, 
            c_S=c_S, 
            c_R=c_R, 
            material='Aluminum')

# Plot phase velocity, group velocity and wavenumber.

alum.plot_phase_velocity()
alum.plot_group_velocity()
alum.plot_wave_number()

# Plot wave structure (displacement profiles across thickness) for A0 
# and S0 modes at different fd values.

alum.plot_wave_structure(mode='A0', nrows=3, ncols=2, 
                         fd=[500,1000,1500,2000,2500,3000])

alum.plot_wave_structure(mode='S0', nrows=4, ncols=2, 
                         fd=[500,1000,1500,2000,2500,3000,3500,4000])

# Generate animations for A0 and S0 modes at 1000 kHz mm.

alum.animate_displacement(mode='S0', fd=1000)
alum.animate_displacement(mode='A0', fd=1000)

# Save all results to a txt file.

alum.save_results()

plt.show()
# Out:
# Calculating symmetric modes..
#
# 0/100 - 0.0 kHz × mm
# 1/100 - 101.0 kHz × mm
# 2/100 - 202.0 kHz × mm
# 3/100 - 303.0 kHz × mm
# 4/100 - 404.0 kHz × mm
# 5/100 - 505.1 kHz × mm
# 6/100 - 606.1 kHz × mm
# 7/100 - 707.1 kHz × mm
# 8/100 - 808.1 kHz × mm
# 9/100 - 909.1 kHz × mm
# 10/100 - 1010.1 kHz × mm
# 11/100 - 1111.1 kHz × mm
# 12/100 - 1212.1 kHz × mm
# 13/100 - 1313.1 kHz × mm
# 14/100 - 1414.1 kHz × mm
# 15/100 - 1515.2 kHz × mm
# 16/100 - 1616.2 kHz × mm
# 17/100 - 1717.2 kHz × mm
# 18/100 - 1818.2 kHz × mm
# 19/100 - 1919.2 kHz × mm
# 20/100 - 2020.2 kHz × mm
# 21/100 - 2121.2 kHz × mm
# 22/100 - 2222.2 kHz × mm
# 23/100 - 2323.2 kHz × mm
# 24/100 - 2424.2 kHz × mm
# 25/100 - 2525.3 kHz × mm
# 26/100 - 2626.3 kHz × mm
# 27/100 - 2727.3 kHz × mm
# 28/100 - 2828.3 kHz × mm
# 29/100 - 2929.3 kHz × mm
# 30/100 - 3030.3 kHz × mm
# 31/100 - 3131.3 kHz × mm
# 32/100 - 3232.3 kHz × mm
# 33/100 - 3333.3 kHz × mm
# 34/100 - 3434.3 kHz × mm
# 35/100 - 3535.4 kHz × mm
# ...
